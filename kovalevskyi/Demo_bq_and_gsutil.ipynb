# %%
import tensorflow as tf
# Out:
# /usr/lib/python3/dist-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
tf.test.is_built_with_cuda()
# Out:
# True

# %%
# !bq --location=EU mk -d --default_table_expiration 3600 --description "Dataset for examples." examples3
# Out:
# Dataset 'ticino-2018:examples3' successfully created.

# %%
# !bq --location=EU load --autodetect --source_format=CSV examples3.airports gs://ingres/airports.csv
# Out:
# Waiting on bqjob_r4410bd78f5143f1f_000001663bb800d7_1 ... (5s) Current status: DONE

# %%
# %load_ext google.cloud.bigquery

# %%
# %%bigquery airports
# SELECT *
# FROM `examples3.airports` limit 20
# Out:
#     AIRPORT_SEQ_ID  AIRPORT_ID AIRPORT             DISPLAY_AIRPORT_NAME  \
# 0          1001401       10014     A01                       Blair Lake
# 1          1001402       10014     A01                       Blair Lake
# 2          1000101       10001     01A             Afognak Lake Airport
# 3          1000301       10003     03A          Bear Creek Mining Strip
# 4          1000401       10004     04A                  Lik Mining Camp
# 5          1000501       10005     05A             Little Squaw Airport
# 6          1000601       10006     06A                     Kizhuyak Bay
# 7          1000701       10007     07A            Klawock Seaplane Base
# 8          1000801       10008     08A         Elizabeth Island Airport
# 9          1000901       10009     09A                  Augustin Island
# 10         1001501       10015     A02             Deadmans Bay Airport
# 11         1001601       10016     A03                Hallo Bay Airport
# ...

# %%
type(airports)
# Out:
# pandas.core.frame.DataFrame

# %%
airports[0:10]
# Out:
#    AIRPORT_SEQ_ID  AIRPORT_ID AIRPORT      DISPLAY_AIRPORT_NAME  \
# 0         1001401       10014     A01                Blair Lake
# 1         1001402       10014     A01                Blair Lake
# 2         1000101       10001     01A      Afognak Lake Airport
# 3         1000301       10003     03A   Bear Creek Mining Strip
# 4         1000401       10004     04A           Lik Mining Camp
# 5         1000501       10005     05A      Little Squaw Airport
# 6         1000601       10006     06A              Kizhuyak Bay
# 7         1000701       10007     07A     Klawock Seaplane Base
# 8         1000801       10008     08A  Elizabeth Island Airport
# 9         1000901       10009     09A           Augustin Island
#
#   DISPLAY_AIRPORT_CITY_NAME_FULL  AIRPORT_WAC_SEQ_ID2  AIRPORT_WAC  \
# 0   Fairbanks/Ft. Wainwright, AK                  101            1
# 1   Fairbanks/Ft. Wainwright, AK                  101            1
# ...

# %%
# !gsutil -m cp -R tutorials gs://ingres/more_tutorials
# Out:
# Copying file://tutorials/premade_estimator.py [Content-Type=text/x-python]...
# Copying file://tutorials/custom_estimator.py [Content-Type=text/x-python]...
# Copying file://tutorials/estimator_test.py [Content-Type=text/x-python]...
# Copying file://tutorials/eager.ipynb [Content-Type=application/octet-stream]...
# Copying file://tutorials/_index.ipynb [Content-Type=application/octet-stream]...
# Copying file://tutorials/iris_data.py [Content-Type=text/x-python]...
# / [6/6 files][ 21.7 KiB/ 21.7 KiB] 100% Done
# Operation completed over 6 objects/21.7 KiB.

# %%
# %%bash
# mkdir workspaces
# cd workspaces
# git clone https://github.com/smurve/ml_practices
# Out:
# Cloning into 'ml_practices'...

# %%
# !pwd
# Out:
# /home/jupyter

# %%
# %%bash
# cd workspaces
# git clone https://github.com/tensorflow/tensorflow
# Out:
# Cloning into 'tensorflow'...

# %%
# !pwd
# Out:
# /home/jupyter

# %%
# !bq --location=EU extract --destination_format CSV --field_delimiter "," --print_header 'ticino-2018:flightdata.ATL_JUNE' gs://ingres/alt_june.csv
# Out:
# Waiting on bqjob_r4c8209c37ab5dfe0_00000166492b7ca7_1 ... (6s) Current status: DONE

# %%
# !gsutil cp gs://ingres/alt_june.csv alt_june.csv
# Out:
# Copying gs://ingres/alt_june.csv...
# / [1 files][ 36.1 MiB/ 36.1 MiB]
# Operation completed over 1 objects/36.1 MiB.

# %%
# !wc -l alt_june.csv
# Out:
# 403359 alt_june.csv
