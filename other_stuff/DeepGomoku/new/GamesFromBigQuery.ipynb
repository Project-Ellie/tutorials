# %%
# %load_ext google.cloud.bigquery

# %%
import google.datalab.bigquery as bq

# %%
query_fastgames="select game from `going-tfx.gomocup_2018.Fastgame`"

# %%
df = bq.Query(query_fastgames).execute().result().to_dataframe()

# %%
df.head()
# Out:
#                                                 game
# 0  j20k20j19k19j18k18j17k17k16j16m16l15j15i14i15g...
# 1  j20k20j19k19j18k18j17k17k16j16m16l15l14n16o15i...
# 2  j20k20j19k19j18k18j17k17k16j16m16l15i15l14k15k...
# 3  j20k20j19k19j18k18j17k17k16j16m16l15i15l14l13m...
# 4  j20k20j19k19j18k18j17k17k16j16m16l15i15l14l13m...

# %%
df.count()
# Out:
# game    22704
# dtype: int64

# %%
import numpy as np
from GomokuBoard import GomokuBoard
from GomokuTools import GomokuTools as gt
from GomokuData import record_game
from NH9x9 import NH9x9
from Heuristics import Heuristics
from HeuristicPolicy import HeuristicGomokuPolicy
import random
import tensorflow as tf

# %%
string = df['game'][0]

# %%
stones = gt.string_to_stones(string)

# %%
heuristics = Heuristics(kappa=3)

# %%
str(s[0])
# Out:
# 'J'

# %%
stones = [(str(s[0]), s[1]) for s in stones]

# %%
board = GomokuBoard(heuristics=heuristics, stones=stones, disp_width=10, N=20 )

# %%
board.fwd().display()
