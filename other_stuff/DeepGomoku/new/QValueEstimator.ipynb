# %%
# %load_ext autoreload
# %autoreload 2

# %%
from __future__ import print_function, absolute_import, division

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from GomokuBoard import GomokuBoard
from Heuristics import Heuristics
from GomokuTools import GomokuTools as gt
from HeuristicPolicy import HeuristicGomokuPolicy

# %%
#board size:
N=20

# %%
def make_tfr_input_fn(filename_pattern, batch_size, N, options):
    
    import tensorflow as tf
    N_p = N + 2
    feature_spec = {
        'state': tf.FixedLenFeature([N_p * N_p * 2], tf.float32),
        'qvalue': tf.FixedLenFeature([N_p * N_p], tf.float32)
    }

    def _input_fn():
        dataset = tf.data.experimental.make_batched_features_dataset(
            file_pattern=filename_pattern,
            batch_size=batch_size,
            features=feature_spec,
            shuffle_buffer_size=options['shuffle_buffer_size'],
            prefetch_buffer_size=options['prefetch_buffer_size'],
            reader_num_threads=options['reader_num_threads'],
            parser_num_threads=options['parser_num_threads'],
            label_key='qvalue')

        if options['distribute']:
            return dataset 
        else:
            return dataset.make_one_shot_iterator().get_next()
    return _input_fn

# %%
options = {
    'shuffle_buffer_size': 1024,
    'prefetch_buffer_size': 1024,
    'reader_num_threads': 4,
    'parser_num_threads': 4,
    'train_data_pattern': "gs://gomoku-data/tfrecords/*",
    'train_batch_size': 512,
    'max_train_steps': 100000,
    'eval_data_pattern': "gs://gomoku-data/tfrecords/*",
    'eval_batch_size': 32,
    'eval_steps': 10,
    'throttle_secs': 120,
    'learning_rate': 1e-3,
    'distribute': False,
    'model_dir': "gs://gomoku-data/model2",
    'save_summary_steps': 64,
    'save_checkpoints_steps': 64,
    'log_step_count_steps': 64,
    'optimizer': 'adam'
}

train_input_fn = make_tfr_input_fn(options['train_data_pattern'], 
                               options['train_batch_size'],
                               N, options)    

eval_input_fn = make_tfr_input_fn(options['eval_data_pattern'], 
                              options['eval_batch_size'],
                              N, options)

# %%
from tensorflow.feature_column import numeric_column as num
feature_columns = [num('state', shape=((N+2)*(N+2)*2))]
feature_columns
# Out:
# [NumericColumn(key='state', shape=(968,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %%
def hypothesis(features, feature_columns, options):

    print("===================================================")
    print("Hypothesis")
    print("===================================================")
    
    #f_state = features['state']
    #reshaped = tf.reshape(f_state, (-1, N+2, N+2, 2))
    #print("===================================================")
    #print(f_state)
    #print(reshaped)
    #print(feature_columns)
    #print("===================================================")
    
    input_layer = tf.feature_column.input_layer( 
        features, feature_columns=feature_columns)

    reshaped = tf.reshape(input_layer, [-1, N+2, N+2, 2], name='reshape_input')
    
    #print("===================================================")
    #print(reshaped)
    #print(input_layer)
    #print("===================================================")

    conv1 = tf.layers.conv2d(inputs=reshaped, filters=256, kernel_size=[9,9], 
                             strides=[1,1], padding='SAME', activation=tf.nn.elu)
    conv2 = tf.layers.conv2d(inputs=conv1, filters=128, kernel_size=[9,9], 
                             strides=[1,1], padding='SAME', activation=tf.nn.elu)
    conv3 = tf.layers.conv2d(inputs=conv2, filters=64, kernel_size=[5,5], 
                             strides=[1,1], padding='SAME', activation=tf.nn.elu)
    conv4 = tf.layers.conv2d(inputs=conv3, filters=16, kernel_size=[5,5], 
                             strides=[1,1], padding='SAME')
    conv5 = tf.layers.conv2d(inputs=conv4, filters=1, kernel_size=[5,5], 
                             strides=[1,1], padding='SAME')

    return conv5

# %%
from make_model_fn import make_model_fn
model_fn = make_model_fn(feature_columns, options, hypothesis)

# %%
def serving_input_fn():
    placeholders = {
        'state': tf.placeholder(name='state', shape=[(N+2)*(N+2)*2, None], dtype=tf.float32)
    }
    return tf.estimator.export.ServingInputReceiver(placeholders, placeholders)

# %%
train_input_fn()
# Out:
# ({'state': <tf.Tensor 'IteratorGetNext_2:0' shape=(512, 968) dtype=float32>},
#  <tf.Tensor 'IteratorGetNext_2:1' shape=(512, 484) dtype=float32>)

# %%
exporter = tf.estimator.LatestExporter('exporter', serving_input_fn)

train_spec = tf.estimator.TrainSpec(
    input_fn=train_input_fn, 
    max_steps=options['max_train_steps'])

eval_spec = tf.estimator.EvalSpec(
    input_fn=eval_input_fn, exporters=exporter,
    steps = options['eval_steps'],
    throttle_secs=options['throttle_secs'],
    start_delay_secs=0)

# %%
from tensorflow.estimator import RunConfig
from tensorflow.contrib.distribute import MirroredStrategy

strategy = MirroredStrategy() if options['distribute'] else None
config = RunConfig(model_dir=options['model_dir'],
                   save_summary_steps=options['save_summary_steps'],
                   train_distribute=strategy, 
                   save_checkpoints_steps=options['save_checkpoints_steps'],
                   log_step_count_steps=options['log_step_count_steps'])

estimator = tf.estimator.Estimator(
        config=config,
        model_fn=model_fn)
# Out:
# INFO:tensorflow:Using config: {'_device_fn': None, '_num_ps_replicas': 0, '_is_chief': True, '_tf_random_seed': None, '_save_checkpoints_secs': None, '_service': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_train_distribute': None, '_save_summary_steps': 64, '_save_checkpoints_steps': 64, '_master': '', '_global_id_in_cluster': 0, '_evaluation_master': '', '_eval_distribute': None, '_model_dir': 'gs://gomoku-data/model2', '_num_worker_replicas': 1, '_task_type': 'worker', '_log_step_count_steps': 64, '_experimental_distribute': None, '_keep_checkpoint_max': 5, '_task_id': 0, '_keep_checkpoint_every_n_hours': 10000, '_protocol': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f993c3ab2e8>}

# %%
##################################################################
#   Finally, train and evaluate the model
##################################################################
final_eval = tf.estimator.train_and_evaluate(
    estimator, 
    train_spec=train_spec, 
    eval_spec=eval_spec)
# Out:
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 64 or save_checkpoints_secs None.
# INFO:tensorflow:Calling model_fn.
# ===================================================
# Mode: train
# ===================================================
# ===================================================
# Hypothesis
# ===================================================
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://gomoku-data/model2/model.ckpt-960
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 960 into gs://gomoku-data/model2/model.ckpt.
# INFO:tensorflow:loss = 5892.7354, step = 960
# INFO:tensorflow:Saving checkpoints for 1024 into gs://gomoku-data/model2/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# ===================================================
# Mode: eval
# ===================================================
# ===================================================
# Hypothesis
# ===================================================
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-08T19:23:41Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://gomoku-data/model2/model.ckpt-1024
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2019-04-08-19:23:43
# INFO:tensorflow:Saving dict for global step 1024: global_step = 1024, loss = 5568.6367, mean_error = 64.93595
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1024: gs://gomoku-data/model2/model.ckpt-1024
# INFO:tensorflow:Calling model_fn.
# ===================================================
# Mode: infer
# ===================================================
# ===================================================
# Hypothesis
# ===================================================
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Restoring parameters from gs://gomoku-data/model2/model.ckpt-1024
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: gs://gomoku-data/model2/export/exporter/temp-b'1554751423'/saved_model.pb
# INFO:tensorflow:global_step/sec: 2.93811
# INFO:tensorflow:loss = 5641.3306, step = 1024 (21.784 sec)
# INFO:tensorflow:Saving checkpoints for 1088 into gs://gomoku-data/model2/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (120 secs).
# INFO:tensorflow:global_step/sec: 5.76784
# INFO:tensorflow:loss = 4657.9844, step = 1088 (11.098 sec)
# INFO:tensorflow:Saving checkpoints for 1152 into gs://gomoku-data/model2/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (120 secs).
# INFO:tensorflow:global_step/sec: 5
into gs://gomoku-data/model2/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (120 secs).
# INFO:tensorflow:global_step/sec: 5.90246
# INFO:tensorflow:loss = 399.26395, step = 5888 (10.842 sec)
# INFO:tensorflow:Saving checkpoints for 5952 into gs://gomoku-data/model2/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (120 secs).
# INFO:tensorflow:global_step/sec: 5.6408
# INFO:tensorflow:loss = 426.2283, step = 5952 (11.346 sec)
# INFO:tensorflow:Saving checkpoints for 6016 into gs://gomoku-data/model2/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (120 secs).
# INFO:tensorflow:global_step/sec: 5.78092
# INFO:tensorflow:loss = 487.22357, step = 6016 (11.071 sec)
# INFO:tensorflow:Saving checkpoints for 6080 into gs://gomoku-data/model2/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (120 secs).
# INFO:tensorflow:global_step/sec: 5.55087
# INFO:tensorflow:loss = 514.07605, step = 6080 (11.531 sec)
# INFO:tensorflow:Saving checkpoints for 6144 into gs://gomoku-data/model2/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# ===================================================
# Mode: eval
# ===================================================
# ===================================================
# Hypothesis
# ===================================================
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-08T19:39:58Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://gomoku-data/model2/model.ckpt-6144
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2019-04-08-19:40:00
# INFO:tensorflow:Saving dict for global step 6144: global_step = 6144, loss = 406.71362, mean_error = 12.18474
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6144: gs://gomoku-data/model2/model.ckpt-6144
# INFO:tensorflow:Calling model_fn.
# ===================================================
# Mode: infer
# ===================================================
# ===================================================
# Hypothesis
# ===================================================
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Restoring parameters from gs://gomoku-data/model2/model.ckpt-6144
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: gs://gomoku-data/model2/export/exporter/temp-b'1554752401'/saved_model.pb
# INFO:tensorflow:global_step/sec: 2.81296
# INFO:tensorflow:loss = 406.8673, step = 6144 (22.751 sec)
# INFO:tensorflow:Saving checkpoints for 6208 into gs://gomoku-data/model2/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (120 secs).
# INFO:tensorflow:global_step/sec: 5.74236
# INFO:tensorflow:loss = 450.2287, step = 6208 (11.145 sec)
# INFO:tensorflow:Saving checkpoints for 6272 into gs://gomoku-data/model2/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (120 secs).
# INFO:tensorflow:global_step/sec: 5.94614
# INFO:tensorflow:loss = 443.28976, step = 6272 (10.763 sec)
# INFO:tensorflow:Saving checkpoints for 6336 into gs://gomoku-data/model2/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (120 secs).
# INFO:tensorflow:global_step/sec: 5.66101
# INFO:tensorflow:loss = 443.27954, step = 6336 (11.306 sec)
# INFO:tensorflow:Saving checkpoints for 6400 into gs://gomoku-data/model2/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (120 secs).
# INFO:tensorflow:global_step/sec: 5.93416
# INFO:tensorflow:loss = 379.37177, step = 6400 (10.787 sec)
# INFO:tensorflow:Saving checkpoints for 6464 into gs://gomoku-data/model2/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (120 secs).
# INFO:tensorflow:global_step/sec: 5.88417
# INFO:tensorflow:loss = 485.49368, step = 6464 (10.874 sec)
# INFO:tensorflow:Saving checkpoints for 6528 into gs://gomoku-data/model2/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (120 secs).
# INFO:tensorflow:global_step/sec: 5.89222
# INFO:tensorflow:loss = 399.645, step = 6528 (10.862 sec)
# INFO:tensorflow:Saving checkpoints for 6592 into gs://gomoku-data/model2/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (120 secs).
# INFO:tensorflow:global_step/sec: 5.82113
# INFO:tensorflow:loss = 389.0973, step = 6592 (10.995 sec)
# INFO:tensorflow:Saving checkpoints for 6656 into gs://gomoku-data/model2/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (120 secs).
# INFO:tensorflow:global_step/sec: 6.00038
# INFO:tensorflow:loss = 384.96088, step = 6656 (10.666 sec)
# INFO:tensorflow:Saving checkpoints for 6720 into gs://gomoku-data/model2/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (120 secs).
# INFO:tensorflow:global_step/sec: 5.73789
# INFO:tensorflow:loss = 434.32968, step = 6720 (11.154 sec)
# INFO:tensorflow:Saving checkpoints for 6784 into gs://gomoku-data/model2/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# ===================================================
# Mode: eval
# ===================================================
# ===================================================
# Hypothesis
# ===================================================
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-08T19:42:00Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://gomoku-data/model2/model.ckpt-6784
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2019-04-08-19:42:01
# INFO:tensorflow:Saving dict for global step 6784: global_step = 6784, loss = 407.60883, mean_error = 11.935124
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6784: gs://gomoku-data/model2/model.ckpt-6784
# INFO:tensorflow:Calling model_fn.
# ===================================================
# Mode: infer
# ===================================================
# ===================================================
# Hypothesis
# ===================================================
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Restoring parameters from gs://gomoku-data/model2/model.ckpt-6784
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: gs://gomoku-data/model2/export/exporter/temp-b'1554752522'/saved_model.pb
# INFO:tensorflow:global_step/sec: 2.82016
# INFO:tensorflow:loss = 406.524, step = 6784 (22.694 sec)
# INFO:tensorflow:Saving checkpoints for 6848 into gs://gomoku-data/model2/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (120 secs).
# INFO:tensorflow:global_step/sec: 5.91195
# INFO:tensorflow:loss = 400.324, step = 6848 (10.828 sec)
# INFO:tensorflow:Saving checkpoints for 6912 into gs://gomoku-data/model2/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (120 secs).
# INFO:tensorflow:global_step/sec: 5.9235
# INFO:tensorflow:loss = 341.40884, step = 6912 (10.803 sec)
# INFO:tensorflow:Saving checkpoints for 6976 into gs://gomoku-data/model2/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (120 secs).
# INFO:tensorflow:global_step/sec: 5.84743
# INFO:tensorflow:loss = 498.53778, step = 6976 (10.944 sec)
# INFO:tensorflow:Saving checkpoints for 7040 into gs://gomoku-data/model2/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (120 secs).
# INFO:tensorflow:global_step/sec: 5

# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/10]
# INFO:tensorflow:Evaluation [2/10]
# INFO:tensorflow:Evaluation [3/10]
# INFO:tensorflow:Evaluation [4/10]
# INFO:tensorflow:Evaluation [5/10]
# INFO:tensorflow:Evaluation [6/10]
# INFO:tensorflow:Evaluation [7/10]
# INFO:tensorflow:Evaluation [8/10]
# INFO:tensorflow:Evaluation [9/10]
# INFO:tensorflow:Evaluation [10/10]
# INFO:tensorflow:Finished evaluation at 2019-04-09-00:46:21
# INFO:tensorflow:Saving dict for global step 100000: global_step = 100000, loss = 158.29019, mean_error = 3.4986093
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 100000: gs://gomoku-data/model2/model.ckpt-100000
# INFO:tensorflow:Calling model_fn.
# ===================================================
# Mode: infer
# ===================================================
# ===================================================
# Hypothesis
# ===================================================
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Restoring parameters from gs://gomoku-data/model2/model.ckpt-100000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: gs://gomoku-data/model2/export/exporter/temp-b'1554770782'/saved_model.pb
# INFO:tensorflow:Loss for final step: 118.86152.

# %%
latest_model=!gsutil ls gs://gomoku-data/model2/export/exporter | grep -v temp | sort | tail -1
latest_model = latest_model[0]
latest_model
# Out:
# 'gs://gomoku-data/model2/export/exporter/1554770782/'

# %%
estimator = tf.contrib.predictor.from_saved_model(latest_model)
# Out:
# WARNING:tensorflow:From /home/wgiersche/env3/lib/python3.5/site-packages/tensorflow/contrib/predictor/saved_model_predictor.py:153: load (from tensorflow.python.saved_model.loader_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.loader.load or tf.compat.v1.saved_model.load. There will be a new function for importing SavedModels in Tensorflow 2.0.
# INFO:tensorflow:Restoring parameters from gs://gomoku-data/model2/export/exporter/1554770782/variables/variables

# %%
from GomokuData import data_from_game
stones=gt.string_to_stones('e10g8g5f5f6e7f7f8e8g9h10d9g10f10h8h9i9g7e9j8h11i12e11e12g11f11f12e13g13h14i10g14j9k8i8k4i7')
heuristics = Heuristics(kappa=3.0)
board = GomokuBoard(heuristics=heuristics, N=20, stones=stones, disp_width=10)
policy = HeuristicGomokuPolicy(board=board, style=2)
board = GomokuBoard(heuristics=heuristics, N=20, stones=stones, disp_width=10)

# %%
board.undo().display()

# %%
data = data_from_game(board, policy, heuristics)
idx = 5
data[0][idx].shape
# Out:
# (22, 22, 2)

# %%
s = data[0][idx]
field = np.rollaxis(s.reshape(22,22,2), 2, 0).astype(np.int)
unwrapped = (field[0]+field[1]*2)[1:-1].T[1:-1].T
unwrapped
r,c = np.where(unwrapped == 1)
moves_b = list(zip(r,c))
r,c = np.where(unwrapped == 2)
moves_w = list(zip(r,c))
moves_b, moves_w = (moves_b, moves_w) if len(moves_b) == len(moves_w) else (moves_w, moves_b)
moves_b = [gt.m2b(move, N) for move in moves_b]
moves_w = [gt.m2b(move, N) for move in moves_w]
if len(moves_b) > len(moves_w):
    last_move = moves_b[-1]
stones=[]
for two_moves in zip(moves_b, moves_w):
    for i in [0, 1]:
        stones.append((two_moves[i][0], two_moves[i][1]))
if len(moves_b) > len(moves_w):
    stones.append((moves_b[-1][0], moves_b[-1][1]))
len(stones)
board = GomokuBoard(heuristics, N, disp_width=8, stones=stones)
board.display()

# %%
sample={'state': np.transpose([s.flatten()])}

# %%
q = estimator(sample)
q = q['output'][0]
q = np.rollaxis(q, 2, 0)
q = np.sign(q)+1
_, x, y = np.where(q==2)

# %%
[gt.m2b(p, 20) for p in list(zip(x,y))]
# Out:
# [array([10, 12]), array([ 7, 11]), array([6, 7]), array([20,  2])]
